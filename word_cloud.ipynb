# %% [markdown]
# # Word Cloud
# * doc: https://amueller.github.io/word_cloud/index.html
# * installation:
#     * pip install wordcloud
#     * conda install -c conda-forge wordcloud

# %% [markdown]
# ---
# * author:  [Prasert Kanawattanachai](prasert.k@chula.ac.th)
# * YouTube: https://www.youtube.com/prasertcbs
# * [Chulalongkorn Business School](https://www.cbs.chula.ac.th/en/)
# ---

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('6pcQ5Vi8rUw', width=720, height=405)
# Out:
#         <iframe
#             width="720"
#             height="405"
#             src="https://www.youtube.com/embed/6pcQ5Vi8rUw"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import wordcloud
from wordcloud import WordCloud, STOPWORDS

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
print(f'pandas    version: {pd.__version__}')
print(f'numpy     version: {np.__version__}')
print(f'wordcloud version: {wordcloud.__version__}')
# Out:
# pandas    version: 1.1.3
# numpy     version: 1.19.2
# wordcloud version: 1.8.1

# %%
pd.Timestamp.now()

# %% [markdown]
# <img src=https://images-na.ssl-images-amazon.com/images/I/6182S7MYC2L._AC_SL1000_.jpg width=400 />

# %%
# https://www.kaggle.com/sid321axn/amazon-alexa-reviews
url='https://github.com/prasertcbs/basic-dataset/raw/master/amazon_alexa.tsv'
df=pd.read_csv(url, sep='\t')
df[:5]
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
word_col='verified_reviews'

# %%
all_words = ' '.join(df[word_col]).lower()
all_words[:500]

# %%
stopwords = set(STOPWORDS)
stopwords.update(["echo", "alexa", "dot", "amazon"])

# %%
print(stopwords)
# Out:
# {"why's", 'down', 'is', 'a', "couldn't", 'shall', 'whom', 'echo', 'been', "you're", 'at', 'here', "here's", "she'll", 'each', 'also', 'being', "haven't", 'http', "you'd", 'else', 'theirs', "isn't", 'both', 'into', 'r', "doesn't", "he's", "there's", 'why', 'or', 'all', "didn't", 'am', 'otherwise', 'some', 'after', 'in', 'herself', "we're", 'the', 'hence', 'further', 'just', "i'll", 'nor', 'can', 'her', 'more', 'ought', 'on', "won't", 'but', 'what', 'than', 'those', 'ever', 'themselves', 'between', "you've", 'only', 'who', 'amazon', 'however', 'he', 'hers', 'you', 'of', "wouldn't", 'have', "shan't", 'up', 'we', 'which', 'its', 'over', 'him', "i'm", 'doing', 'not', 'any', 'against', 'has', 'off', "what's", 'our', "they'll", 'since', 'above', "they're", 'yourself', 'for', "i'd", 'very', 'your', 'myself', 'ours', 'few', "hadn't", 'about', "hasn't", "i've", 'no', 'could', 'if', "they've", "who's", 'me', 'before', 'them', 'are', 'get', 'out', 'same', 'should', 'below', "how's", 'once', "can't", 'during', "mustn't", 'she', 'com', "they'd", 'www', 'cannot', 'other', 'and', "shouldn't", 'so', "let's", 'with', 'most', 'dot', 'was', 'k', 'when', 'too', 'from', 'ourselves', 'again', 'because', "aren't", 'did', 'it', 'this', 'under', "don't", "it's", 'to', "when's", "you'll", "wasn't", 'would', 'does', 'having', 'had', "she'd", 'itself', "we've", 'i', 'own', 'they', "where's", 'be', 'as', 'yours', 'an', 'by', "weren't", 'alexa', 'then', 'my', 'these', "that's", 'like', 'until', 'while', 'how', 'were', 'yourselves', "he'd", 'therefore', "we'd", 'such', 'there', "we'll", 'where', 'do', 'himself', 'their', "she's", 'through', 'his', "he'll", 'that'}

# %%
# https://matplotlib.org/3.3.3/tutorials/colors/colormaps.html

wordcloud = WordCloud(
    stopwords=stopwords,
    width=2000, height=1000,
#     colormap='viridis', # default matplotlib colormap
#     colormap='tab20c',
    colormap='plasma',
#     max_font_size=50, 
    max_words=50, 
    background_color = 'white').generate(all_words)
plt.figure(figsize = (10, 9))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
# plt.show()

# %%
# read the mask image
from PIL import Image

# mask_img_file='cloud.png'
# mask_img_file='speaker.png'
mask_img_file='mask2.png'
# mask_img_file='A_mask.png'

mask = np.array(Image.open(mask_img_file).convert('RGBA'))

# %%
# https://matplotlib.org/3.3.3/tutorials/colors/colormaps.html

wordcloud = WordCloud(
    stopwords=stopwords,
    width=2000, height=1000,
#     colormap='viridis', # default matplotlib colormap
#     colormap='tab20c',
    colormap='plasma',
#     max_font_size=50, 
    max_words=50, 
    mask=mask,
    background_color = 'white').generate(all_words)
plt.figure(figsize = (16, 9))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
wordcloud.words_
# Out:
# {'love': 1.0,
#  'use': 0.4984583761562179,
#  'music': 0.4244604316546763,
#  'great': 0.42137718396711205,
#  'device': 0.34121274409044194,
#  'work': 0.32476875642343267,
#  'one': 0.31654676258992803,
#  'easy': 0.29290853031860226,
#  'set': 0.29290853031860226,
#  'thing': 0.26002055498458376,
#  'time': 0.2528263103802672,
#  'good': 0.24563206577595068,
#  'speaker': 0.2302158273381295,
#  'sound': 0.22918807810894143,
#  'product': 0.20554984583761562,
#  'show': 0.20246659815005139,
#  'will': 0.19835560123329907,
#  'new': 0.1963001027749229,
#  'really': 0.1778006166495375,
#  'now': 0.1685508735868448,
#  'play': 0.16752312435765673,
#  'bought': 0.16752312435765673,
#  's': 0.16238437821171633,
#  'fun': 0.1593011305241521,
#  'light': 0.15210688591983557,
#  'need': 0.1510791366906475,
#  'far': 0.14902363823227133,
#  'works great': 0.14799588900308325,
#  'home': 0.1408016443987667,
#  'much': 0.13566289825282632,
#  'got': 0.13052415210688592,
#  'better': 0.13052415210688592,
#  'plus': 0.12846865364850976,
#  'everything': 0.12332990750256938,
#  'house': 0.11819116135662898,
#  'ask': 0.11613566289825282,
#  'turn': 0.11510791366906475,
#  'screen': 0.11510791366906475,
#  'even': 0.11408016443987667,
#  'app': 0.11408016443987667,
#  'make': 0.11099691675231244,
#  'able': 0.10996916752312436,
#  'well': 0.10894141829393628,
#  'still': 0.1079136690647482,
#  'little': 0.10688591983556012,
#  'spot': 0.10688591983556012,
#  'want': 0.10585817060637205,
#  'feature': 0.10483042137718397,
#  'alarm': 0.10174717368961973,
#  'using': 0.10174717368961973}

# %%
wordcloud.to_file("wordcloud.png")
